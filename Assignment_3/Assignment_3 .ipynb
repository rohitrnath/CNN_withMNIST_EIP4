50
# 390/390 [==============================] - 21s 54ms/step - loss: 0.3965 - acc: 0.8656 - val_loss: 0.5558 - val_acc: 0.8211
# Epoch 32/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3938 - acc: 0.8656 - val_loss: 0.5606 - val_acc: 0.8229
# Epoch 33/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3800 - acc: 0.8702 - val_loss: 0.5529 - val_acc: 0.8239
# Epoch 34/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3849 - acc: 0.8707 - val_loss: 0.5762 - val_acc: 0.8173
# Epoch 35/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3720 - acc: 0.8744 - val_loss: 0.5646 - val_acc: 0.8196
# Epoch 36/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3735 - acc: 0.8747 - val_loss: 0.5750 - val_acc: 0.8182
# Epoch 37/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3702 - acc: 0.8740 - val_loss: 0.5515 - val_acc: 0.8271
# Epoch 38/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3574 - acc: 0.8786 - val_loss: 0.5575 - val_acc: 0.8238
# Epoch 39/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3634 - acc: 0.8782 - val_loss: 0.5546 - val_acc: 0.8280
# Epoch 40/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3577 - acc: 0.8783 - val_loss: 0.5583 - val_acc: 0.8215
# Epoch 41/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3453 - acc: 0.8835 - val_loss: 0.5711 - val_acc: 0.8285
# Epoch 42/50
# 390/390 [==============================] - 21s 54ms/step - loss: 0.3543 - acc: 0.8810 - val_loss: 0.5767 - val_acc: 0.8267
# Epoch 43/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3512 - acc: 0.8816 - val_loss: 0.5921 - val_acc: 0.8244
# Epoch 44/50
# 390/390 [==============================] - 21s 54ms/step - loss: 0.3458 - acc: 0.8826 - val_loss: 0.5490 - val_acc: 0.8322
# Epoch 45/50
# 390/390 [==============================] - 21s 54ms/step - loss: 0.3347 - acc: 0.8880 - val_loss: 0.5604 - val_acc: 0.8221
# Epoch 46/50
# 390/390 [==============================] - 21s 54ms/step - loss: 0.3368 - acc: 0.8862 - val_loss: 0.5864 - val_acc: 0.8199
# Epoch 47/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3311 - acc: 0.8893 - val_loss: 0.5752 - val_acc: 0.8227
# Epoch 48/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3327 - acc: 0.8863 - val_loss: 0.5607 - val_acc: 0.8254
# Epoch 49/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3301 - acc: 0.8910 - val_loss: 0.5729 - val_acc: 0.8261
# Epoch 50/50
# 390/390 [==============================] - 21s 53ms/step - loss: 0.3270 - acc: 0.8918 - val_loss: 0.5619 - val_acc: 0.8275
# Model took 1036.83 seconds to train
# Accuracy on test data is: 82.75

# %%
from keras.layers.convolutional import SeparableConv2D

# %%
newModel = Sequential()

newModel.add(SeparableConv2D(48, 3, 3, activation='relu', input_shape=(32, 32, 3))) #30,3 (output size, receptive field)
newModel.add(BatchNormalization())
newModel.add(Dropout(0.2))

newModel.add(SeparableConv2D(96, kernel_size = (3, 3), activation='relu' )) #28,5
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

newModel.add(SeparableConv2D(192, kernel_size = (3, 3),  strides=(2, 2), activation='relu' )) #13,7
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

#newModel.add(MaxPooling2D(pool_size=(2, 2))) #14,8

newModel.add(SeparableConv2D(48, 3, 3, activation='relu', )) #11,9
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

newModel.add(SeparableConv2D(96, 3, 3, activation='relu', )) #9,11
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

newModel.add(SeparableConv2D(192, kernel_size = (3, 3), strides=(2, 2), activation='relu', )) #4, 13
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

#newModel.add(MaxPooling2D(pool_size=(2, 2))) #4,9

newModel.add(SeparableConv2D(48, 3, 3, activation='relu', )) #2,17
newModel.add(BatchNormalization())
newModel.add(Dropout(0.1))

newModel.add(SeparableConv2D(num_classes, 1, activation='relu')) # (1, 17)
newModel.add(BatchNormalization())

newModel.add(Flatten())
#newModel.add(Activation('softmax')) #(1, 23)
newModel.add(Dense(num_classes, activation='softmax'))
newModel.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(48, (3, 3), activation="relu", input_shape=(32, 32, 3...)`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(48, (3, 3), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(96, (3, 3), activation="relu")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: UserWarning: Update your `SeparableConv2D` call to the Keras 2 API: `SeparableConv2D(48, (3, 3), activation="relu")`

# %%
newModel.summary()
# Out:
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# separable_conv2d_243 (Separa (None, 30, 30, 48)        219
# _________________________________________________________________
# batch_normalization_229 (Bat (None, 30, 30, 48)        192
# _________________________________________________________________
# dropout_216 (Dropout)        (None, 30, 30, 48)        0
# _________________________________________________________________
# separable_conv2d_244 (Separa (None, 28, 28, 96)        5136
# _________________________________________________________________
# batch_normalization_230 (Bat (None, 28, 28, 96)        384
# _________________________________________________________________
# dropout_217 (Dropout)        (None, 28, 28, 96)        0
# _________________________________________________________________
# separable_conv2d_245 (Separa (None, 13, 13, 192)       19488
# _________________________________________________________________
# batch_normalization_231 (Bat (None, 13, 13, 192)       768
# _________________________________________________________________
# dropout_218 (Dropout)        (None, 13, 13, 192)       0
# _________________________________________________________________
# separable_conv2d_246 (Separa (None, 11, 11, 48)        10992
# _________________________________________________________________
# batch_normalization_232 (Bat (None, 11, 11, 48)        192
# _________________________________________________________________
# dropout_219 (Dropout)        (None, 11, 11, 48)        0
# _________________________________________________________________
# separable_conv2d_247 (Separa (None, 9, 9, 96)          5136
# _________________________________________________________________
# batch_normalization_233 (Bat (None, 9, 9, 96)          384
# _________________________________________________________________
# dropout_220 (Dropout)        (None, 9, 9, 96)          0
# _________________________________________________________________
# separable_conv2d_248 (Separa (None, 4, 4, 192)         19488
# _________________________________________________________________
# batch_normalization_234 (Bat (None, 4, 4, 192)         768
# _________________________________________________________________
# dropout_221 (Dropout)        (None, 4, 4, 192)         0
# _________________________________________________________________
# separable_conv2d_249 (Separa (None, 2, 2, 48)          10992
# _________________________________________________________________
# batch_normalization_235 (Bat (None, 2, 2, 48)          192
# _________________________________________________________________
# dropout_222 (Dropout)        (None, 2, 2, 48)          0
# _________________________________________________________________
# separable_conv2d_250 (Separa (None, 2, 2, 10)          538
# _________________________________________________________________
# batch_normalization_236 (Bat (None, 2, 2, 10)          40
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 40)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 10)                410
# =================================================================
# Total params: 75,319
# Trainable params: 73,859
# Non-trainable params: 1,460
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)
# train the model
start = time.time()
# Train the model
newModel_info = newModel.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 50, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=50)`
#